# %% [markdown]
# ***What is World Happiness Report (2021) ?***

# %% [markdown]
# The United Nation’s Sustainable Development Solutions Network published the world happiness report on 19th March 2021 that ranks the world's 149 countries on how happy their citizens perceive themselves to be based on various indicators. The happiness study ranks the countries on the basis of questions from the Gallup World Poll. The results are then equated with other factors such as GDP, life expectancy, generosity, etc. In the year 2021, it focused on the effects of the Covid-19 pandemic and how people all over the world have managed to survive and prosper.

# %% [markdown]
# ***Import necessary libraries***

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 15
plt.rcParams['figure.figsize'] = (10,7)
plt.rcParams['figure.facecolor'] = '#FFE5B4'

# %%
# loading the World Happiness DataSetdata 
data = pd.read_csv("C:\\Users\\pansh\\Downloads\\world-happiness-report-2021.csv")
data
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
data.shape
# Out:
# (149, 20)

# %%
# Check NaN values
data.isnull().sum()
# Out:
# Country name                                  0
# Regional indicator                            0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       0
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         0
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           0
# ...

# %%
# keeping only required columns

# %%
data = data[ ['Country name','Regional indicator','Ladder score','Logged GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption'] ]
data
# Out:
#     Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# 0        Finland      Western Europe         7.842                 10.775
# 1        Denmark      Western Europe         7.620                 10.933
# 2    Switzerland      Western Europe         7.571                 11.117
# 3        Iceland      Western Europe         7.554                 10.878
# 4    Netherlands      Western Europe         7.464                 10.932
# ..           ...                 ...           ...                    ...
# 144      Lesotho  Sub-Saharan Africa         3.512                  7.926
# 145     Botswana  Sub-Saharan Africa         3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa         3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa         3.145                  7.943
# 148  Afghanistan          South Asia         2.523                  7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
# renaming the column name

# %%
data.columns = ['Country_Name','Regional_Indicator','Happiness_Score','Logged_GDP_per_capita','Social_Support','Healthy_Life_Expectancy','Freedom_to_make_life_choices','Generosity','Perceptions_of_corruption']
data.head()
# Out:
#   Country_Name Regional_Indicator  Happiness_Score  Logged_GDP_per_capita  \
# 0      Finland     Western Europe            7.842                 10.775
# 1      Denmark     Western Europe            7.620                 10.933
# 2  Switzerland     Western Europe            7.571                 11.117
# 3      Iceland     Western Europe            7.554                 10.878
# 4  Netherlands     Western Europe            7.464                 10.932
#
#    Social_Support  Healthy_Life_Expectancy  Freedom_to_make_life_choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions_of_corruption
# ...

# %% [markdown]
# ***What is GDP per Capita ?***
# GDP stands for Gross Domestic Product. GDP per capita is a measure that calculates the economic output of a country divided by its total population. It is used to measure a country's economic productivity on a per-person basis and is often used as an indicator of a country's standard of living. GDP per capita is calculated by dividing a country's GDP by its total population, and it provides a useful way to compare the economic output of different countries, regardless of their size or population.

# %% [markdown]
# ***What is Happiness Score ?***
#  The Happiness Score is a measure of well-being and happiness of a country's citizens, based on several factors such as GDP per capita, social support, life expectancy, freedom to make life choices, generosity, and perceptions of corruption. The Happiness Score is a value between 0 and 10, with higher scores indicating greater levels of happiness and well-being.

# %%
# plot b/w 'Happiness Score' and 'GDP per capita'

# %%
plt.title("plot b/w 'Happiness Score' and 'Logged GDP per capita'")
sns.set(rc={'figure.figsize':(15,7)})
sns.scatterplot(x= data.Happiness_Score, y= data.Logged_GDP_per_capita, hue= data.Regional_Indicator, s=200)
plt.legend(loc='upper left',fontsize='10')
plt.xlabel('Happiness Score')
plt.ylabel('GDP per capita')
plt.show()

# %% [markdown]
# ***What is Regional Indicator ?***
# "Regional_Indicator" is a categorical variable that indicates the region to which each country belongs. The regions are:
#
# Western Europe,
# North America and ANZ,
# Middle East and North Africa ,
# Latin America and Caribbean,
# Central and Eastern Europe
# East Asia,
# Southeast Asia,
# Commonwealth of Independent States,
# Sub-Saharan Africa,
# South Asia.

# %% [markdown]
# ***What is GDP per Capita ?***
# GDP stands for Gross Domestic Product. GDP per capita is a measure that calculates the economic output of a country divided by its total population. It is used to measure a country's economic productivity on a per-person basis and is often used as an indicator of a country's standard of living. GDP per capita is calculated by dividing a country's GDP by its total population, and it provides a useful way to compare the economic output of different countries, regardless of their size or population.

# %%
# Groups the data by 'Regional_Indicator' column and Calculates the sum of 'Logged_GDP_per_capita' for each group.

region = data.groupby('Regional_Indicator')[['Logged_GDP_per_capita']].sum()
region
# Out:
#                                     Logged_GDP_per_capita
# Regional_Indicator
# Central and Eastern Europe                        171.854
# Commonwealth of Independent States                112.822
# East Asia                                          62.206
# Latin America and Caribbean                       187.400
# Middle East and North Africa                      164.324
# North America and ANZ                              43.238
# South Asia                                         60.778
# Southeast Asia                                     84.793
# Sub-Saharan Africa                                290.707
# Western Europe                                    227.277

# %%
# Generates a pie chart showing the distribution of GDP by region
import matplotlib.pyplot as plt

region = data.groupby('Regional_Indicator')['Logged_GDP_per_capita'].sum()

plt.pie(region, labels=region.index, autopct='%1.1f%%')
plt.title('Distribution of GDP by region')
plt.ylabel('')
plt.show()

# %%
# Calculates the total number of countries in each region

total_country = data.groupby('Regional_Indicator')[['Country_Name']].count()
total_country
# Out:
#                                     Country_Name
# Regional_Indicator
# Central and Eastern Europe                    17
# Commonwealth of Independent States            12
# East Asia                                      6
# Latin America and Caribbean                   20
# Middle East and North Africa                  17
# North America and ANZ                          4
# South Asia                                     7
# Southeast Asia                                 9
# Sub-Saharan Africa                            36
# Western Europe                                21

# %%
# Correlation Map
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

cor = data.corr(method='pearson')
f, ax = plt.subplots(figsize=(10, 5))
sns.heatmap(cor, mask=np.zeros_like(cor, dtype=bool), cmap='Blues', square=True, ax=ax)
# Out:
# C:\Users\pansh\AppData\Local\Temp\ipykernel_4700\892612498.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = data.corr(method='pearson')
# <Axes: >

# %% [markdown]
# ***What is Perceptions of Corruption ?***
#  "Perceptions_of_corruption" is a column that indicates the perceived levels of public sector corruption in each country, as reported in the Gallup World Poll. The values range from 0 to 1, where 0 indicates a perception of high levels of corruption, and 1 indicates a perception of low levels of corruption.

# %% [markdown]
# ***What is Regional Indicator ?*** "Regional_Indicator" is a categorical variable that indicates the region to which each country belongs. The regions are:
#
# Western Europe, North America and ANZ, Middle East and North Africa , Latin America and Caribbean, Central and Eastern Europe East Asia, Southeast Asia, Commonwealth of Independent States, Sub-Saharan Africa, South Asia.

# %%
# Show the average corruption perception score for each region.

corruptions = data.groupby('Regional_Indicator')[['Perceptions_of_corruption']].mean()
corruptions
# Out:
#                                     Perceptions_of_corruption
# Regional_Indicator
# Central and Eastern Europe                           0.850529
# Commonwealth of Independent States                   0.725083
# East Asia                                            0.683333
# Latin America and Caribbean                          0.792600
# Middle East and North Africa                         0.762235
# North America and ANZ                                0.449250
# South Asia                                           0.797429
# Southeast Asia                                       0.709111
# Sub-Saharan Africa                                   0.765944
# Western Europe                                       0.523095

# %%
# plot a bar chart of the mean perceptions of corruption in each region

plt.rcParams['figure.figsize'] = (12,8)
plt.title('Perception of the Corruption in various Regions')
plt.xlabel('Regions', fontsize=15)
plt.ylabel('Corruption', fontsize=15)
plt.xticks(rotation=30, ha='right')
plt.bar(corruptions.index, corruptions.Perceptions_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ***What is Countries Life Expectancy ?***
#  "Healthy Life Expectancy" represents the life expectancy in years for each country.

# %%
top_10 = data.head(10)
bottom_10 = data.tail(10)

# %%
#  Plot for top 10 happiest countries based on healty life expectancy
fig, axes= plt.subplots(1,2,figsize=(16,6))
plt.tight_layout(pad=2)
xlabels=top_10.Country_Name
axes[0].set_title("Top 10 Happiest Countries Life Expectancy")
axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x=top_10.Country_Name, y=top_10.Healthy_Life_Expectancy, ax=axes[0])
axes[0].set_xlabel('Country Name')
axes[0].set_ylabel('Life Expectancy')

#  Plot for top 10 Least happiest countries based on life expectancy
xlabels=bottom_10.Country_Name
axes[1].set_title("Top 10 Least Happiest Countries Life Expectancy")
axes[1].set_xticklabels(xlabels, rotation=45, ha='right')
sns.barplot(x=bottom_10.Country_Name, y=bottom_10.Healthy_Life_Expectancy, ax=axes[1])
axes[1].set_xlabel('Country Name')
axes[1].set_ylabel('Life Expectancy')
# Out:
# C:\Users\pansh\AppData\Local\Temp\ipykernel_4700\2852751622.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[0].set_xticklabels(xlabels, rotation=45, ha='right')
# C:\Users\pansh\AppData\Local\Temp\ipykernel_4700\2852751622.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes[1].set_xticklabels(xlabels, rotation=45, ha='right')
# Text(836.2386363636361, 0.5, 'Life Expectancy')

# %% [markdown]
# ***What is the freedom to make life choices ?***
#
# The "Freedom to make life choices" is one of the variables in the World Happiness Report dataset, which measures the national average score on the question "Are you satisfied or dissatisfied with your freedom to choose what you do with your life?". It is a measure of the perceived level of individual freedom in making important life decisions.

# %%
# show the relationship between the freedom to make life choices and happiness score for different regions
plt.rcParams['figure.figsize'] = (15,7)
plt.title('Relationship between the freedom to make life choices and happiness score for different regions')
sns.scatterplot(x= data.Freedom_to_make_life_choices, y= data.Happiness_Score, hue= data.Regional_Indicator)
plt.legend(loc='upper left',fontsize='12')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')

# %%
# plot the corruption index of the top 10 countries with the least perception of corruption
country = data.sort_values(by='Perceptions_of_corruption').head(10)
plt.rcParams['figure.figsize'] = (12,6)
plt.title('Top 10 countries with the least perception of corruption')
plt.xlabel('Country Name', fontsize=15)
plt.ylabel('Corruption Index', fontsize=15)
plt.xticks(rotation=30, ha='right')
plt.bar(country.Country_Name, corruptions.Perceptions_of_corruption)
# Out:
# <BarContainer object of 10 artists>

# %%
# visualize the relationship between the Happiness Score and the Perceptions of Corruption of countries in different regions.
plt.rcParams['figure.figsize'] = (15,7)
plt.title('The relationship between the Happiness Score and the Perceptions of Corruption of countries in different regions.')
sns.scatterplot(x= data.Happiness_Score, y= data.Perceptions_of_corruption, hue= data.Regional_Indicator)
plt.legend(loc='lower left',fontsize='12')
plt.xlabel('Corruption')
plt.ylabel('Happiness Score')
# Out:
# Text(0, 0.5, 'Happiness Score')
